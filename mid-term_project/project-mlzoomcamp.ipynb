# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mutual_info_score, accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('/kaggle/input/wine-quality-dataset/WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
print(df.shape)
# Out:
# (1143, 13)

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 15.0                  65.0   0.9959  3.28       0.54
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4
# 5      9.4        5   5
# 6      9.4        5   6
# 7     10.0        7   7
# 8      9.5        7   8
# 9      9.2        5  10

# %%
df.columns = df.columns.str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.replace(' ', '_')

# %%
df.rename(columns={'pH': 'ph'}, inplace=True)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1143 non-null   float64
#  1   volatile_acidity      1143 non-null   float64
#  2   citric_acid           1143 non-null   float64
#  3   residual_sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free_sulfur_dioxide   1143 non-null   float64
#  6   total_sulfur_dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
sns.histplot(df.quality, bins=50)
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.250728     0.673157
# volatile_acidity          -0.250728          1.000000    -0.544187
# citric_acid                0.673157         -0.544187     1.000000
# residual_sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free_sulfur_dioxide       -0.164831         -0.001962    -0.057589
# total_sulfur_dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity               0.171831   0.107889            -0.164831
# volatile_acidity           -0.005751   0.056336            -0.001962
# citric_acid                 0.175815   0.245312            -0.057589
# residual_sugar              1.000000   0.070863             0.165339
# chlorides                   0.070863   1.000000             0.015280
# free_sulfur_dioxide         0.165339   0.015280             1.000000
# total_sulfur_dioxide        0.190790   0.048163             0.661093
# density                     0.380147   0.208901            -0.054150
# pH                         -0.116959  -0.277759             0.072804
# sulphates                   0.017475   0.374784             0.034445
# alcohol                     0.058421  -0.229917            -0.047095
# quality                     0.022002  -0.124085            -0.063260
# Id                         -0.046344  -0.088099             0.095268
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.110628  0.681501 -0.685163   0.174592
# volatile_acidity                  0.077748  0.016512  0.221492  -0.276079
# citric_acid                       0.036871  0.375243 -0.546339   0.331232
# residual_sugar                    0.190790  0.380147 -0.116959   0.017475
# chlorides                         0.048163  0.208901 -0.277759   0.374784
# free_sulfur_dioxide               0.661093 -0.054150  0.072804   0.034445
# total_sulfur_dioxide              1.000000  0.050175 -0.059126   0.026894
# density                           0.050175  1.000000 -0.352775   0.143139
# pH                               -0.059126 -0.352775  1.000000  -0.185499
# sulphates                         0.026894  0.143139 -0.185499   1.000000
# alcohol                          -0.188165 -0.494727  0.225322   0.094421
# quality                          -0.183339 -0.175208 -0.052453   0.257710
# Id                               -0.107389 -0.363926  0.132904  -0.103954
#
#                        alcohol   quality        Id
# fixed_acidity        -0.075055  0.121970 -0.275826
# volatile_acidity     -0.203909 -0.407394 -0.007892
# citric_acid           0.106250  0.240821 -0.139011
# residual_sugar        0.058421  0.022002 -0.046344
# chlorides            -0.229917 -0.124085 -0.088099
# free_sulfur_dioxide  -0.047095 -0.063260  0.095268
# total_sulfur_dioxide -0.188165 -0.183339 -0.107389
# density              -0.494727 -0.175208 -0.363926
# pH                    0.225322 -0.052453  0.132904
# sulphates             0.094421  0.257710 -0.103954
# alcohol               1.000000  0.484866  0.238087
# quality               0.484866  1.000000  0.069708
# Id                    0.238087  0.069708  1.000000

# %%
plt.figure(figsize=(9, 6))
sns.heatmap(df.corr(), cmap="summer", annot=True, fmt='.3f')
plt.title('Correlation Heatmap')
plt.show();

# %%
df.corr().unstack().sort_values(ascending = False)
# Out:
# fixed_acidity     fixed_acidity       1.000000
# volatile_acidity  volatile_acidity    1.000000
# quality           quality             1.000000
# alcohol           alcohol             1.000000
# sulphates         sulphates           1.000000
#                                         ...
# volatile_acidity  citric_acid        -0.544187
# citric_acid       pH                 -0.546339
# pH                citric_acid        -0.546339
# fixed_acidity     pH                 -0.685163
# pH                fixed_acidity      -0.685163
# Length: 169, dtype: float64

# %% [markdown]
# Splitting into train, valid and test

# %%
X_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(X_full_train, test_size=0.25, random_state=1)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)


y_train = df_train.quality.values
y_val = df_val.quality.values
y_test = df_test.quality.values

del df_train['quality']
del df_val['quality']
del df_test['quality']

# %%
dv = DictVectorizer(sparse=False)
train_dict = df_train.to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

model = LogisticRegression(solver='liblinear', max_iter=1000, C=10, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)

y_pred = model.predict(X_val)

# %%
accuracy = np.round(accuracy_score(y_val, y_pred),2)
print(f'Accuracy = {accuracy}')
# Out:
# Accuracy = 0.63

# %%
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 0.6406874037664375

# %%
features = df.columns.to_list()
features
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'Id']

# %%
#finding the least useful feature using the feature elimination technique
original_score = accuracy
scores = pd.DataFrame(columns=['eliminated_feature', 'accuracy', 'difference'])
for feature in features:
    subset = features.copy()
    subset.remove(feature)
    
    model = LogisticRegression(solver='liblinear', max_iter=1000, C=10, random_state=42)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    score = accuracy_score(y_val, y_pred)
    
    scores.loc[len(scores)] = [feature, score, original_score - score]

# %%
#All feautures are equally important
scores
# Out:
#       eliminated_feature  accuracy  difference
# 0          fixed_acidity  0.628821    0.001179
# 1       volatile_acidity  0.628821    0.001179
# 2            citric_acid  0.628821    0.001179
# 3         residual_sugar  0.628821    0.001179
# 4              chlorides  0.628821    0.001179
# 5    free_sulfur_dioxide  0.628821    0.001179
# 6   total_sulfur_dioxide  0.628821    0.001179
# 7                density  0.628821    0.001179
# 8                     pH  0.628821    0.001179
# 9              sulphates  0.628821    0.001179
# 10               alcohol  0.628821    0.001179
# 11               quality  0.628821    0.001179
# 12                    Id  0.628821    0.001179

# %%
from sklearn.model_selection import KFold
columns = list(df.columns)
columns
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'Id']

# %%
def train(df_train, y_train, C=1.0):
    dicts = df_train[columns].to_dict(orient='records')

    dv = DictVectorizer()
    X_train = dv.fit_transform(dicts)

    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000)
    model.fit(X_train, y_train)

    return dv, model

def predict(df, dv, model):
    dicts = df_val[columns].to_dict(orient='records')

    X_val = dv.transform(dicts)
    y_pred = model.predict(X_val)

    return y_pred

# %% [markdown]
# Validating KFold to find best score

# %%
scores = []

kfold = KFold(n_splits=5, shuffle=True, random_state=1)

for train_idx, val_idx in kfold.split(X_full_train):
    df_train = X_full_train.iloc[train_idx]
    df_val = X_full_train.iloc[val_idx]

    y_train = df_train.quality.values
    y_val = df_val.quality.values

    dv, model = train(df_train, y_train, C=1.0)
    y_pred = predict(df_val, dv, model)

    sc = accuracy_score(y_val, y_pred)
    scores.append(sc)

print('%.3f +- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# 0.879 +- 0.025

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=1)

for C in [0.01, 0.1, 0.5, 10]:
    scores = []

    for train_idx, val_idx in kfold.split(X_full_train):
        df_train = X_full_train.iloc[train_idx]
        df_val = X_full_train.iloc[val_idx]

        y_train = df_train.quality.values
        y_val = df_val.quality.values


        dv, model = train(df_train, y_train, C=C)
        y_pred = predict(df_val, dv, model)

        sc = accuracy_score(y_val, y_pred)
        scores.append(sc)

    print('C=%4s, %.3f +- %.3f' % (C, np.mean(scores), np.std(scores)))
# Out:
# C=0.01, 0.640 +- 0.032
# C= 0.1, 0.788 +- 0.019
# C= 0.5, 0.850 +- 0.021
# C=  10, 0.905 +- 0.021

# %% [markdown]
# Since C =10 achieves the best score, I trained the model again with that C value

# %%
def train(df_train, y_train, C=10):
    dicts = df_train[columns].to_dict(orient='records')

    dv = DictVectorizer()
    X_train = dv.fit_transform(dicts)

    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000)
    model.fit(X_train, y_train)

    return dv, model

def predict(df, dv, model):
    dicts = df_val[columns].to_dict(orient='records')

    X_val = dv.transform(dicts)
    y_pred = model.predict(X_val)

    return y_pred

# %%
#Final accuray was good.
accuracy = np.round(accuracy_score(y_val, y_pred),2)
print(f'Accuracy = {accuracy}')
# Out:
# Accuracy = 0.92

# %%
# I could reduce the least RMSE value
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 0.3144854510165755

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (1.3.2)

# %%
import pickle

# Save the model to a file
filename = 'model.bin'
dv = 'dv.bin'
with open(filename, 'wb') as file:
    pickle.dump(filename, file)

with open(dv, 'wb') as file:
    pickle.dump(dv, file)

# %% [markdown]
# Experiment with Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/kaggle/input/wine-quality-dataset/WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.columns = df.columns.str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.replace(' ', '_')
   
df.rename(columns={'pH': 'ph'}, inplace=True)

# %%
 df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
#delete ID from dataset
df = df.drop(columns=['Id'])

df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#Splitting dataset into train, test, valid

X_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(X_full_train, test_size=0.25, random_state=1)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)


y_train = df_train.quality.values
y_val = df_val.quality.values
y_test = df_test.quality.values

del df_train['quality']
del df_val['quality']
del df_test['quality']

# %%
train_dicts = df_train.to_dict(orient='records')
dv = DictVectorizer(sparse=True)
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val.to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=1, n_jobs=-1)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 0.5948835708624806

# %%
from tqdm.auto import tqdm

# %%
#trained the Random Forest Regressor with n_estimators up to 150
scores = []

for n in tqdm(range(10, 151, 10)):
    rf = RandomForestRegressor(n_estimators=n, random_state=1, n_jobs=-1)
    rf.fit(X_train, y_train)
    
    y_pred = rf.predict(X_val)
    score = np.sqrt(mean_squared_error(y_val, y_pred))
    
    scores.append((n, score))

df_scores = pd.DataFrame(scores, columns=['n_estimators', 'rmse'])
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# n_estimators 100 can provide the least rsme score
df_scores
# Out:
#     n_estimators      rmse
# 0             10  0.594884
# 1             20  0.582543
# 2             30  0.573953
# 3             40  0.572240
# 4             50  0.569382
# 5             60  0.570526
# 6             70  0.568880
# 7             80  0.568231
# 8             90  0.566639
# 9            100  0.566531
# 10           110  0.567764
# 11           120  0.571058
# 12           130  0.571098
# 13           140  0.572339
# 14           150  0.573257

# %%
plt.plot(df_scores.n_estimators, df_scores.rmse)
plt.plot(df_scores.n_estimators, df_scores.rmse.round(3))

plt.show()

# %%
scores = []

rf = RandomForestRegressor(
    n_estimators=1,
    random_state=1,
    n_jobs=-1,
    warm_start=True,
)

for n in tqdm(range(10, 151, 10)):
    rf.n_estimators = n
    rf.fit(X_train, y_train)
    
    y_pred = rf.predict(X_val)
    score = np.sqrt(mean_squared_error(y_val, y_pred))
    
    scores.append((n, score))

df_scores = pd.DataFrame(scores, columns=['n_estimators', 'rmse'])
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
plt.plot(df_scores.n_estimators, df_scores.rmse.round(3))
plt.show()

# %%
# trained the model again with various depth

scores = []

for d in tqdm([10, 15, 20, 25, 30, 35]):
    rf = RandomForestRegressor(
        n_estimators=0,
        max_depth=d,
        random_state=1,
        n_jobs=-1,
        warm_start=True
    )

    for n in tqdm(range(10, 151, 10)):
        rf.n_estimators = n
        rf.fit(X_train, y_train)

        y_pred = rf.predict(X_val)
        score = np.sqrt(mean_squared_error(y_val, y_pred))

        scores.append((d, n, score))

columns = ['max_depth', 'n_estimators', 'rmse']
df_scores = pd.DataFrame(scores, columns=columns)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# max_depth=35 produced least rmse score

for d in [10, 15, 20, 25, 30, 35]:
    df_subset = df_scores[df_scores.max_depth == d]
    plt.plot(df_subset.n_estimators, df_subset.rmse.round(3), label=d)

plt.legend()
plt.show()

# %%
#So Finally trained again with n_estimators =100 and max_depth =35
rf = RandomForestRegressor(
    n_estimators=100,
    max_depth=35,
    random_state=1,
    n_jobs=-1
)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=35, n_jobs=-1, random_state=1)

# %%
# It can reduce rmse score but it is still higher than the rmse of logstic regression model.
y_pred = rf.predict(X_val)
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 0.5665308510930139
